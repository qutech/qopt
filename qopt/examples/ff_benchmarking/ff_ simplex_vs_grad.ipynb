# %%
import datetime
import os.path
import numpy as np
from qopt.examples.ff_benchmarking.singlet_triplet_setup import \
    create_simulators, create_optimizer, EPS_MIN, N_TIME_STEPS, \
    create_bounded_nm
from qopt.analyser import Analyser
from qopt.data_container import DataContainer


def time_stamp():
    time = str(datetime.datetime.now())[:-7]
    new_time = time[:10] + '-' + time[11:13] + '-' + time[14:16] \
               + '-' + time[17:19]
    return new_time


n_runs = 50

np.random.seed(0)
initial_conditions = EPS_MIN * np.random.rand(N_TIME_STEPS, n_runs)

path = r'Z:\SimulationData\ff_derivative\ff_simplex_vs_grad'

# %%
# n_time_steps = 10
n_time_steps = 20

# %%
simulator_ff, simulator_l, simulator_syst, sim_ff_only = create_simulators(
    n_time_steps)

ls_opt = create_optimizer(simulator_ff)
nm_opt = create_bounded_nm(simulator_ff)

# %%
ls_data = DataContainer(storage_path=path)
for i in range(n_runs):
    ls_result =  ls_opt.run_optimization(
        initial_control_amplitudes=np.expand_dims(
            initial_conditions[:, i], axis=1
        )
    )

    ls_data.append_optim_result(ls_result)

ls_analyser = Analyser(data=ls_data)
ls_file = r'least-squares' + time_stamp()
ls_data.to_pickle(filename=os.path.join(path, ls_file))

# %%
nm_data = DataContainer(storage_path=path)
for i in range(n_runs):
    nm_result =  nm_opt.run_optimization(
        initial_control_amplitudes=np.expand_dims(
            initial_conditions[:, i], axis=1
        ))

    nm_data.append_optim_result(nm_result)

nm_analyser = Analyser(data=nm_data)
nm_file = r'nelder-mead' + time_stamp()
nm_data.to_pickle(filename=os.path.join(path, nm_file))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-6d25b04effdf> in <module>
#       3     nm_result =  nm_opt.run_optimization(
#       4         initial_control_amplitudes=np.expand_dims(
# ----> 5             initial_conditions[:, i], axis=1
#       6         ))
#       7
#
# ~\Documents\qopt\qopt\examples\ff_benchmarking\singlet_triplet_setup.py in run_optimization(self, initial_control_amplitudes)
#      70                 UB=np.asarray(self.uppter_bounds),
#      71                 maxiter=self.termination_conditions["max_iterations"],
# ---> 72                 maxfun=self.termination_conditions["max_cost_func_calls"]
#      73             )
#      74
#
# ~\AppData\Local\Continuum\miniconda3\envs\qopt_ff_isabel\lib\site-packages\constrnmpy-0.2-py3.7.egg\constrNMPy\constrNMPy.py in constrNM(func, x0, LB, UB, args, xtol, ftol, maxiter, maxfun, full_output, disp, retall, callback)
#      75     # Call fmin
#      76     res=sciopt.fmin(constrObjFunc,x0,args=opts,ftol=ftol,xtol=xtol,maxiter=maxiter,disp=disp,
# ---> 77          full_output=full_output,callback=callback,maxfun=maxfun,retall=retall)
#      78
#      79     # Convert res to list
#
# ~\AppData\Local\Continuum\miniconda3\envs\qopt_ff_isabel\lib\site-packages\scipy\optimize\optimize.py in fmin(func, x0, args, xtol, ftol, maxiter, maxfun, full_output, disp, retall, callback, initial_simplex)
#     541             'initial_simplex': initial_simplex}
#     542
# --> 543     res = _minimize_neldermead(func, x0, args, callback=callback, **opts)
#     544     if full_output:
#     545         retlist = res['x'], res['fun'], res['nit'], res['nfev'], res['status']
#
# ~\AppData\Local\Continuum\miniconda3\envs\qopt_ff_isabel\lib\site-packages\scipy\optimize\optimize.py in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, **unknown_options)
#     734                     # Perform an inside contraction
#     735                     xcc = (1 - psi) * xbar + psi * sim[-1]
# --> 736                     fxcc = func(xcc)
#     737
#     738                     if fxcc < fsim[-1]:
#
# ~\AppData\Local\Continuum\miniconda3\envs\qopt_ff_isabel\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     425     def function_wrapper(*wrapper_args):
#     426         ncalls[0] += 1
# --> 427         return function(*(wrapper_args + args))
#     428
#     429     return ncalls, function_wrapper
#
# ~\AppData\Local\Continuum\miniconda3\envs\qopt_ff_isabel\lib\site-packages\constrnmpy-0.2-py3.7.egg\constrNMPy\constrNMPy.py in constrObjFunc(x, func, LB, UB, args)
#     131     #raw_input()
#     132
# --> 133     return func(x,*args)
#     134
#     135 def transformX(x,LB,UB,offset=1E-20):
#
# ~\Documents\qopt\qopt\optimize.py in cost_fktn_wrapper(self, optimization_parameters)
#     413     def cost_fktn_wrapper(self, optimization_parameters):
#     414         """ See base class. """
# --> 415         costs = super().cost_fktn_wrapper(optimization_parameters)
#     416         scalar_costs = np.sum(costs ** 2)
#     417         return scalar_costs
#
# ~\Documents\qopt\qopt\optimize.py in cost_fktn_wrapper(self, optimization_parameters)
#     158
#     159         costs = self.system_simulator.wrapped_cost_functions(
# --> 160             optimization_parameters.reshape(self.pulse_shape[::-1]).T)
#     161
#     162         if self.save_intermediary_steps:
#
# ~\Documents\qopt\qopt\simulator.py in wrapped_cost_functions(self, pulse)
#     205             for i, cost_fktn in enumerate(self.cost_fktns):
#     206                 t_start = time.time()
# --> 207                 cost = cost_fktn.costs()
#     208                 t_end = time.time()
#     209                 self.stats.cost_func_eval_times[-1].append(t_end - t_start)
#
# ~\Documents\qopt\qopt\cost_functions.py in costs(self)
#    1123             pulse=self.solver.pulse_sequence,
#    1124             S=self.noise_power_spec_density(self.omega),
# -> 1125             omega=self.omega)
#    1126         return infidelity
#    1127
#
# c:\users\teske\documents\isabel-filter_functions\filter_functions\numeric.py in infidelity(pulse, S, omega, n_oper_identifiers, which, return_smallness, test_convergence)
#     925             F = np.einsum('ako,blo,kl->abo', R.conj(), R, Tp)/pulse.d
#     926         else:
# --> 927             F = pulse.get_filter_function(omega)
#     928     elif which == 'correlations':
#     929         if not pulse.basis.istraceless:
#
# c:\users\teske\documents\isabel-filter_functions\filter_functions\pulse_sequence.py in get_filter_function(self, omega, show_progressbar)
#     538         # Cache filter function
#     539         self.cache_filter_function(
# --> 540             omega, R=self.get_control_matrix(omega, show_progressbar)
#     541         )
#     542
#
# c:\users\teske\documents\isabel-filter_functions\filter_functions\pulse_sequence.py in get_control_matrix(self, omega, show_progressbar)
#     457         R = calculate_control_matrix_from_scratch(
#     458             self.HD, self.HV, self.Q, omega, self.basis, self.n_opers,
# --> 459             self.n_coeffs, self.dt, self.t, show_progressbar=show_progressbar
#     460         )
#     461
#
# c:\users\teske\documents\isabel-filter_functions\filter_functions\numeric.py in calculate_control_matrix_from_scratch(HD, HV, Q, omega, basis, n_opers, n_coeffs, dt, t, show_progressbar)
#     231         QdagV = np.einsum('lba,lbc->lac', Q[:-1].conj(), HV)
#     232         B = np.einsum('lba,jbc,lcd->jlad', HV.conj(), n_opers, HV,
# --> 233                       optimize=['einsum_path', (0, 1), (0, 1)])
#     234     else:
#     235         QdagV = Q[:-1].transpose(0, 2, 1).conj() @ HV
#
# <__array_function__ internals> in einsum(*args, **kwargs)
#
# ~\AppData\Local\Continuum\miniconda3\envs\qopt_ff_isabel\lib\site-packages\numpy\core\einsumfunc.py in einsum(*operands, **kwargs)
#    1406
#    1407             # Contract!
# -> 1408             new_view = tensordot(*tmp_operands, axes=(tuple(left_pos), tuple(right_pos)))
#    1409
#    1410             # Build a new view if needed
#
# <__array_function__ internals> in tensordot(*args, **kwargs)
#
# ~\AppData\Local\Continuum\miniconda3\envs\qopt_ff_isabel\lib\site-packages\numpy\core\numeric.py in tensordot(a, b, axes)
#    1100     at = a.transpose(newaxes_a).reshape(newshape_a)
#    1101     bt = b.transpose(newaxes_b).reshape(newshape_b)
# -> 1102     res = dot(at, bt)
#    1103     return res.reshape(olda + oldb)
#    1104
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Analysis

# %%
file = r'least-squares2020-08-24-15-28-14'

# %%
loaded_data = DataContainer.from_pickle(filename=os.path.join(path, file))
loaded_analyser = Analyser(loaded_data)
fig, ax = loaded_analyser.plot_absolute_costs()
fig.savefig(fname=os.path.join(path, file + '.png'))

# %%
file = r'nelder-mead2020-08-24-15-38-57'
